# %% [markdown]
# # 01: Explore Satellite Data
#
# Goal: Load Sentinel-2 imagery for a crisis-prone region and visualize NDVI.

# %%
import sys
sys.path.append('../src')

from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

from crisiscortex.data.satellite import load_sentinel_tile

# Target region: Sahel (Mali/Niger border)
# Known food insecurity hotspot
BBOX = (-5.0, 12.0, 15.0, 20.0)  # (min_lon, min_lat, max_lon, max_lat)

# TODO: Download sample data via SentinelHub
# TODO: Compute and visualize NDVI = (NIR - Red) / (NIR + Red)
